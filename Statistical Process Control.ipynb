# %% [markdown]
# # Statistical Process Control

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pyspc as spc

# %% [markdown]
# # Xbar R Chart

# %%
xbardata = pd.read_excel('https://github.com/Mohamedghabri/Lean_Six_Sigma/blob/main/xbardata.xlsx?raw=true')

# %%
xbardata.head()
# Out:
#       P1     P2     P3
# 0  0.477  0.475  0.472
# 1  0.475  0.475  0.474
# 2  0.475  0.477  0.475
# 3  0.476  0.474  0.477
# 4  0.475  0.476  0.475

# %%
from pyspc import *
a = spc(xbardata) + xbar_rbar() + rbar() + rules()
print(a)
# Out:
# <pyspc: (-9223372032081731160)>

# %% [markdown]
# # Xbar S Chart

# %%
from pyspc import *
a = spc(xbardata) + xbar_rbar() + sbar() + rules()
print(a)
# Out:
# <pyspc: (-9223372032072199540)>

# %% [markdown]
# # NP Chart

# %%
npdata = pd.read_excel("https://github.com/Mohamedghabri/Lean_Six_Sigma/blob/main/npdata.xlsx?raw=true")

# %%
from pyspc import *
a = spc(npdata) + np() + rules()
print(a)
# Out:
# <pyspc: (-9223372032072233868)>

# %% [markdown]
# # P Chart

# %%
pdata = pd.read_excel("https://github.com/Mohamedghabri/Lean_Six_Sigma/blob/main/pdata.xlsx?raw=true")

# %%
from pyspc import *
a = spc(pdata) + p() + rules()
print(a)
# Out:
# <pyspc: (-9223372032072235356)>
